# %%
print("𝙒𝙚𝙡𝙘𝙤𝙢𝙚 𝙩𝙤 𝙎𝙞𝙢𝙥𝙡𝙚 𝙌𝙪𝙞𝙯 𝘾𝙝𝙖𝙩𝙗𝙤𝙩 🚀")
print("✨ 𝘼𝙣𝙨𝙬𝙚𝙧 𝙩𝙝𝙚 𝙦𝙪𝙚𝙨𝙩𝙞𝙤𝙣𝙨 𝙗𝙮 𝙩𝙮𝙥𝙞𝙣𝙜 𝙖, 𝙗, 𝙘 𝙤𝙧 𝙙\n")

score = 0

questions = [
    {
        "Question": "1. What does AI stand for?",
        "a": "Automatic Intelligence",
        "b": "Artificial Intelligence",
        "c": "Advanced Internet",
        "d": "Active Input",
        "Answer": "b"
    },
    {
        "Question": "2. Which of the following is a type of machine learning?",
        "a": "Supervised Learning",
        "b": "Manual Learning",
        "c": "Human Learning",
        "d": "Guided Learning",
        "Answer": "a"
    },
    {
        "Question": "3. Which AI technique is used to recognize patterns in images?",
        "a": "Neural Networks",
        "b": "Decision Trees",
        "c": "K-Means Clustering",
        "d": "Linear Regression",
        "Answer": "a"
    },
    {
        "Question": "4. Who is considered the father of Artificial Intelligence?",
        "a": "Alan Turing",
        "b": "Isaac Newton",
        "c": "Albert Einstein",
        "d": "Charles Babbage",
        "Answer": "a"
    },
    {
        "Question": "5. Which language is most commonly used for AI and machine learning?",
        "a": "Python",
        "b": "HTML",
        "c": "C",
        "d": "JavaScript",
        "Answer": "a"
    },
    {
        "Question": "6. What is NLP in AI?",
        "a": "Natural Language Processing",
        "b": "Neural Logic Program",
        "c": "Networked Learning Protocol",
        "d": "Numerical Linear Programming",
        "Answer": "a"
    },
    {
        "Question": "7. Which AI type tries to mimic human decision-making?",
        "a": "Narrow AI",
        "b": "General AI",
        "c": "Weak AI",
        "d": "Machine AI",
        "Answer": "b"
    },
    {
        "Question": "8. Which algorithm is commonly used for classification tasks?",
        "a": "Decision Tree",
        "b": "K-Means",
        "c": "Linear Search",
        "d": "Bubble Sort",
        "Answer": "a"
    },
    {
        "Question": "9. What is a chatbot?",
        "a": "A software that paints pictures",
        "b": "A software that simulates human conversation",
        "c": "A hardware device",
        "d": "A type of neural network",
        "Answer": "b"
    },
    {
        "Question": "10. What is the main goal of reinforcement learning?",
        "a": "To predict the future",
        "b": "To learn by trial and error",
        "c": "To store data",
        "d": "To process natural language",
        "Answer": "b"
    }
]

for q in questions:
    print(q["Question"])
    print("a)", q["a"])
    print("b)", q["b"])
    print("c)", q["c"])
    print("d)", q["d"])

    user_ans = input("Your answer: ").lower()
    if user_ans == q["Answer"].lower():
        print("Correct!\n")
        score += 1
    else:
        print("Wrong! Correct answer is:", q["Answer"], "\n")

print("Your final score:", score, "/", len(questions))
# Out:
# 𝙒𝙚𝙡𝙘𝙤𝙢𝙚 𝙩𝙤 𝙎𝙞𝙢𝙥𝙡𝙚 𝙌𝙪𝙞𝙯 𝘾𝙝𝙖𝙩𝙗𝙤𝙩 🚀
# ✨ 𝘼𝙣𝙨𝙬𝙚𝙧 𝙩𝙝𝙚 𝙦𝙪𝙚𝙨𝙩𝙞𝙤𝙣𝙨 𝙗𝙮 𝙩𝙮𝙥𝙞𝙣𝙜 𝙖, 𝙗, 𝙘 𝙤𝙧 𝙙
#
# 1. What does AI stand for?
# a) Automatic Intelligence
# b) Artificial Intelligence
# c) Advanced Internet
# d) Active Input
# Your answer:  b
# Correct!
#
# 2. Which of the following is a type of machine learning?
# a) Supervised Learning
# b) Manual Learning
# c) Human Learning
# d) Guided Learning
# Your answer:  a
# Correct!
#
# 3. Which AI technique is used to recognize patterns in images?
# a) Neural Networks
# b) Decision Trees
# c) K-Means Clustering
# d) Linear Regression
# Your answer:  a
# Correct!
#
# 4. Who is considered the father of Artificial Intelligence?
# a) Alan Turing
# b) Isaac Newton
# c) Albert Einstein
# d) Charles Babbage
# Your answer:  a
# Correct!
#
# 5. Which language is most commonly used for AI and machine learning?
# a) Python
# b) HTML
# c) C
# d) JavaScript
# Your answer:  a
# Correct!
#
# 6. What is NLP in AI?
# a) Natural Language Processing
# ...
